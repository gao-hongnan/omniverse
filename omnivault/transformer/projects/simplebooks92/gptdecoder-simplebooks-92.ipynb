# %% [markdown]
# # GPTDecoder: SimpleBooks-92
#
# - V18: b828879
# - V20-21: ffd2392d886795bc26086e15c33a17934602f11b

# %%
# !git clone --branch main https://github.com/gao-hongnan/omniverse.git
# Out:
# Cloning into 'omniverse'...
# remote: Enumerating objects: 6767, done.
# remote: Counting objects: 100% (578/578), done.
# remote: Compressing objects: 100% (252/252), done.
# remote: Total 6767 (delta 383), reused 477 (delta 287), pack-reused 6189
# Receiving objects: 100% (6767/6767), 16.29 MiB | 15.58 MiB/s, done.
# Resolving deltas: 100% (4237/4237), done.

# %%
# %cd /kaggle/working/omniverse
# !git checkout 2de36b119217348181b0fb1c4aa8d71fdcb3c56e
# Out:
# /kaggle/working/omniverse

# %%
# !pip install -q --upgrade keras-nlp
# !pip install -q --upgrade keras  # Upgrade to Keras 3.
# !pip install tensorflow>=2.15.0
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.13.0 requires keras<2.14,>=2.13.1, but you have keras 3.0.4 which is incompatible.
# tensorflowjs 4.14.0 requires packaging~=23.1, but you have packaging 21.3 which is incompatible.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflowjs 4.14.0 requires packaging~=23.1, but you have packaging 21.3 which is incompatible.

# %%
# %pip install -q -r requirements.txt
# %pip install -U torch torchaudio --no-cache-dir
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.7 which is incompatible.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, but you have numpy 1.26.4 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 11.0.0 which is incompatible.
# beatrix-jupyterlab 2023.814.150030 requires jupyter-server~=1.16, but you have jupyter-server 2.12.1 which is incompatible.
# beatrix-jupyterlab 2023.814.150030 requires jupyterlab~=3.4, but you have jupyterlab 4.0.5 which is incompatible.
# cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.2.0 which is incompatible.
# cudf 23.8.0 requires protobuf<5,>=4.21, but you have protobuf 3.20.3 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2023.12.0 which is incompatible.
# cuml 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.12.0 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2023.12.0 which is incompatible.
# dask-cuda 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.12.0 which is incompatible.
# dask-cuda 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.2.0 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2023.12.0 which is incompatible.
# dask-cudf 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.12.0 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.2.0 which is incompatible.
# fastai 2.7.13 requires torch<2.2,>=1.10, but you have torch 2.2.0 which is incompatible.
# jupyterlab 4.0.5 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.0.1 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.0.1 requires jupyterlab<5.0.0a0,>=4.0.6, but you have jupyterlab 4.0.5 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# numba 0.57.1 requires numpy<1.25,>=1.21, but you have numpy 1.26.4 which is incompatible.
# pymc3 3.11.5 requires numpy<1.22.2,>=1.15.0, but you have numpy 1.26.4 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.11.4 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2023.12.0 which is incompatible.
# raft-dask 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.12.0 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# tensorflow 2.13.0 requires numpy<=1.24.3,>=1.22, but you have numpy 1.26.4 which is incompatible.
# tensorflow 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.9.0 which is incompatible.
# tensorflow-probability 0.21.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# tensorflowjs 4.14.0 requires packaging~=23.1, but you have packaging 21.3 which is incompatible.
# woodwork 0.27.0 requires numpy<1.25.0,>=1.22.0, but you have numpy 1.26.4 which is incompatible.
# ydata-profiling 4.5.1 requires numpy<1.24,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# ydata-profiling 4.5.1 requires pandas!=1.4.0,<2.1,>1.1, but you have pandas 2.2.0 which is incompatible.
# ydata-profiling 4.5.1 requires pydantic<2,>=1.8.1, but you have pydantic 2.5.2 which is incompatible.
# ydata-profiling 4.5.1 requires seaborn<0.13,>=0.10.1, but you have seaborn 0.13.2 which is incompatible.
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: torch in /opt/conda/lib/python3.10/site-packages (2.2.0)
# Requirement already satisfied: torchaudio in /opt/conda/lib/python3.10/site-packages (2.0.1)
# Collecting torchaudio
#   Obtaining dependency information for torchaudio from https://files.pythonhosted.org/packages/30/fc/cdcf7c2071539ea147ddb6de2b538d9c1599665b621f2e6cf0b3ef51d20d/torchaudio-2.2.0-cp310-cp310-manylinux1_x86_64.whl.metadata
#   Downloading torchaudio-2.2.0-cp310-cp310-manylinux1_x86_64.whl.metadata (6.4 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch) (3.12.2)
# Collecting typing-extensions>=4.8.0 (from torch)
#   Obtaining dependency information for typing-extensions>=4.8.0 from https://files.pythonhosted.org/packages/b7/f4/6a90020cd2d93349b442bfcb657d0dc91eee65491600b2cb1d388bc98e6b/typing_extensions-4.9.0-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.9.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch) (2023.12.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /opt/conda/lib/python3.10/site-packages (from torch) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.10/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.10/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.10/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.10/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.10/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /opt/conda/lib/python3.10/site-packages (from torch) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.10/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /opt/conda/lib/python3.10/site-packages (from torch) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.3.101)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch) (1.3.0)
# Downloading torchaudio-2.2.0-cp310-cp310-manylinux1_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 58.4 MB/s eta 0:00:00
# Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# WARNING: Error parsing requirements for numpy: [Errno 2] No such file or directory: '/opt/conda/lib/python3.10/site-packages/numpy-1.26.2.dist-info/METADATA'
# Installing collected packages: typing-extensions, torchaudio
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.7.1
#     Uninstalling typing_extensions-4.7.1:
#       Successfully uninstalled typing_extensions-4.7.1
#   Attempting uninstall: torchaudio
#     Found existing installation: torchaudio 2.0.1
#     Uninstalling torchaudio-2.0.1:
#       Successfully uninstalled torchaudio-2.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# altair 5.2.0 requires numpy, which is not installed.
# apache-beam 2.46.0 requires numpy<1.25.0,>=1.14.3, which is not installed.
# arviz 0.12.1 requires numpy>=1.12, which is not installed.
# chex 0.1.85 requires numpy>=1.24.1, which is not installed.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.8.0 requires numpy>=1.21, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires numpy>=1.21, which is not installed.
# flax 0.7.5 requires numpy>=1.22, which is not installed.
# gymnasium 0.29.0 requires numpy>=1.21.0, which is not installed.
# kaggle-environments 1.14.3 requires numpy>=1.19.5, which is not installed.
# librosa 0.10.1 requires numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3, which is not installed.
# optax 0.1.7 requires numpy>=1.18.0, which is not installed.
# optuna 3.5.0 requires numpy, which is not installed.
# orbax-checkpoint 0.4.7 requires numpy, which is not installed.
# pandasql 0.7.3 requires numpy, which is not installed.
# pettingzoo 1.24.0 requires numpy>=1.21.0, which is not installed.
# pymc3 3.11.5 requires numpy<1.22.2,>=1.15.0, which is not installed.
# pytorch-lightning 2.1.2 requires numpy>=1.17.2, which is not installed.
# qudida 0.0.4 requires numpy>=0.18.0, which is not installed.
# spacy 3.7.2 requires numpy>=1.19.0; python_version >= "3.9", which is not installed.
# stable-baselines3 2.1.0 requires numpy>=1.20, which is not installed.
# tensorflow 2.13.0 requires numpy<=1.24.3,>=1.22, which is not installed.
# tensorflow-decision-forests 1.5.0 requires numpy, which is not installed.
# tensorflow-probability 0.21.0 requires numpy>=1.13.3, which is not installed.
# tensorflow-transform 0.14.0 requires numpy<2,>=1.16, which is not installed.
# thinc 8.2.1 requires numpy>=1.19.0; python_version >= "3.9", which is not installed.
# torchmetrics 1.3.1 requires numpy>1.20.0, which is not installed.
# torchtext 0.15.1 requires numpy, which is not installed.
# torchvision 0.17.0 requires numpy, which is not installed.
# transformers 4.36.0 requires numpy>=1.17, which is not installed.
# vaex-core 4.17.1 requires numpy>=1.16, which is not installed.
# ydata-profiling 4.5.1 requires numpy<1.24,>=1.16.0, which is not installed.
# apache-beam 2.46.0 requires dill<0.3.2,>=0.3.1.1, but you have dill 0.3.7 which is incompatible.
# apache-beam 2.46.0 requires pyarrow<10.0.0,>=3.0.0, but you have pyarrow 11.0.0 which is incompatible.
# cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# cudf 23.8.0 requires protobuf<5,>=4.21, but you have protobuf 3.20.3 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2023.12.0 which is incompatible.
# cuml 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.12.0 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2023.12.0 which is incompatible.
# dask-cudf 23.8.0 requires distributed==2023.7.1, but you have distributed 2023.12.0 which is incompatible.
# dask-cudf 23.8.0 requires pandas<1.6.0dev0,>=1.3, but you have pandas 2.1.4 which is incompatible.
# jupyterlab 4.0.5 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.0.1 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# jupyterlab-lsp 5.0.1 requires jupyterlab<5.0.0a0,>=4.0.6, but you have jupyterlab 4.0.5 which is incompatible.
# pymc3 3.11.5 requires scipy<1.8.0,>=1.7.3, but you have scipy 1.11.4 which is incompatible.
# tensorflow 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.9.0 which is incompatible.
# tensorflow-probability 0.21.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# tensorflowjs 4.14.0 requires packaging~=23.1, but you have packaging 21.3 which is incompatible.
# ydata-profiling 4.5.1 requires pandas!=1.4.0,<2.1,>1.1, but you have pandas 2.1.4 which is incompatible.
# ydata-profiling 4.5.1 requires pydantic<2,>=1.8.1, but you have pydantic 2.5.2 which is incompatible.
# ydata-profiling 4.5.1 requires seaborn<0.13,>=0.10.1, but you have seaborn 0.13.2 which is incompatible.
# Successfully installed torchaudio-2.2.0 typing-extensions-4.9.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys

if "/kaggle/working/omniverse" not in sys.path:
    sys.path.append("/kaggle/working/omniverse")

# %%
# import os

# # Set the environment variable
# os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'expandable_segments:True'

# # Verify that it's set
# print(os.environ['PYTORCH_CUDA_ALLOC_CONF'])

# %%
import math
from typing import Dict, List, Optional

import matplotlib.pyplot as plt


def save_plot_history(history: Dict[str, List[float]], plot: bool = False, save_path: Optional[str] = None) -> None:
    plt.rcParams["font.family"] = "DejaVu Sans"

    num_metrics = len(history.keys())
    num_cols = 2
    num_rows = math.ceil(num_metrics / num_cols)

    fig, axs = plt.subplots(num_rows, num_cols, figsize=(15, 10))

    axs = axs.flatten()

    for i, metric in enumerate(history.keys()):
        axs[i].plot(history[metric])
        axs[i].set_title(metric)
        axs[i].xaxis.set_major_locator(plt.MaxNLocator(integer=True))

    # Remove unused subplots
    for i in range(num_metrics, len(axs)):
        fig.delaxes(axs[i])

    plt.tight_layout()

    if plot:
        plt.show()  # type: ignore[no-untyped-call]

    if save_path is not None:
        plt.savefig(save_path, bbox_inches="tight", dpi=300)

# %%
# type: ignore
import os
import pickle
from typing import Any, Callable, List, Tuple

import keras
import keras_nlp
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
import torch
from keras.saving import deserialize_keras_object
from keras_nlp.samplers import Sampler
from numpy.typing import NDArray
from tensorflow.python.framework.ops import EagerTensor
from torch import nn
from torch.utils.data import DataLoader, Dataset
from tqdm import tqdm
from keras.saving import serialize_keras_object
from pathlib import Path
from omnivault.transformer.config.composer import Composer
from omnivault.transformer.config.criterion import CRITERION_REGISTRY
from omnivault.transformer.config.decoder import (
    AddNormConfig,
    DecoderBlockConfig,
    DecoderConfig,
    MultiHeadedAttentionConfig,
    PositionwiseFeedForwardConfig,
)
from omnivault.transformer.config.generator import GeneratorConfig
from omnivault.transformer.config.optim import OPTIMIZER_REGISTRY
from omnivault.transformer.config.scheduler import SCHEDULER_REGISTRY
from omnivault.transformer.config.trainer import TrainerConfig
from omnivault.transformer.core.dataset import (
    construct_dummy_batch_future_masks,
    construct_dummy_batch_target_padding_masks,
)
from omnivault.transformer.core.state import State
from omnivault.transformer.core.trainer import Trainer, TrainerEvent
from omnivault.transformer.decoder.core import GPTDecoder
from omnivault.transformer.modules.attention.core import ScaledDotProductAttention
from omnivault.utils.torch_utils.cleanup import purge_global_scope
from omnivault.utils.reproducibility.seed import seed_all

# from omnivault.transformer.utils.visualization import save_plot_history
from rich.pretty import pprint

seed_all(seed=20230310, set_torch_deterministic=False)
tf.random.set_seed(20230310)

# Paths
DATA_URL: str = "https://dldata-public.s3.us-east-2.amazonaws.com/simplebooks.zip"
BASE_DATA_DIR: str = os.path.join(os.path.expanduser("~/.keras/datasets/"), "simplebooks/")
TRAIN_FILE: str = os.path.join(BASE_DATA_DIR, "simplebooks-92-raw/train.txt")
VALID_FILE: str = os.path.join(BASE_DATA_DIR, "simplebooks-92-raw/valid.txt")

TRAIN_DATASET_PICKLED_PATH = "/kaggle/input/simplebooks-92/train_dataset.pkl"
VALID_DATASET_PICKLED_PATH = "/kaggle/input/simplebooks-92/valid_dataset.pkl"
SAVE_DATASET_AS_PICKLE = True
LOAD_DATASET_FROM_PICKLE = False
COMPUTE_WORD_PIECE_VOCABULARY = True


# Data
BATCH_SIZE = 64
MIN_STRING_LEN = 512  # Strings shorter than this will be discarded
SEQ_LEN = 128  # Length of training sequences, in tokens

# Vocabulary
VOCABULARY_SERIALIZABLED: str = "/kaggle/input/simplebooks-92/vocabulary_serializabled.pkl"
VOCAB_SIZE = 5000  # Limits parameters in model.

# Training
GRADIENT_ACCUMULATION_STEPS = 4
BASE_LR = 0.00025
BASE_TRAIN_BATCH_SIZE = 16
NUM_GPUS = 1

# Inference
NUM_TOKENS_TO_GENERATE = 80


def download_and_extract_data(url: str) -> str:
    """Download and extract dataset from a given URL."""
    return keras.utils.get_file(origin=url, extract=True)


def load_and_prepare_dataset(
    file_path: str, batch_size: int, min_string_len: int, shuffle: bool = False, mode: str = "train"
) -> tf.data.TextLineDataset:
    """Prepare the dataset by loading, filtering and batching."""
    dataset = tf.data.TextLineDataset(file_path)
    dataset = dataset.filter(lambda x: tf.strings.length(x) > min_string_len)
    dataset = dataset.batch(batch_size)
    if shuffle:
        dataset = dataset.shuffle(buffer_size=256)

    return dataset


def load_vocab(vocab_file: str) -> List[str]:
    """Load the vocabulary from a serialized file."""
    try:
        with open(vocab_file, "rb") as f:
            vocab_config = pickle.load(f)
    except FileNotFoundError:
        raise Exception(f"Vocabulary file not found: {vocab_file}") from None
    except Exception as err:
        raise Exception(f"Error loading vocabulary: {str(err)}") from err

    return deserialize_keras_object(vocab_config)


def create_tokenizer(vocabulary: List[str], seq_len: int) -> keras_nlp.tokenizers.WordPieceTokenizer:
    """
    Create a WordPiece tokenizer and a StartEnd packer using the given
    vocabulary and sequence length.
    """
    tokenizer = keras_nlp.tokenizers.WordPieceTokenizer(
        vocabulary=vocabulary,
        sequence_length=seq_len,
        lowercase=True,
    )

    return tokenizer


def create_start_packer(tokenizer: keras_nlp.tokenizers.WordPieceTokenizer) -> keras_nlp.layers.StartEndPacker:
    """Create a StartEnd packer using the given tokenizer."""
    assert tokenizer.sequence_length == SEQ_LEN
    return keras_nlp.layers.StartEndPacker(
        sequence_length=tokenizer.sequence_length,
        start_value=tokenizer.token_to_id("[BOS]"),
    )


def preprocess(inputs: tf.Tensor) -> Tuple[tf.Tensor, tf.Tensor]:
    """
    Preprocess the input data by tokenizing and then packing with start tokens.

    Parameters
    ----------
    inputs : tf.Tensor
        Input text data in tensor format.

    Returns
    -------
    Tuple[tf.Tensor, tf.Tensor]
        A tuple containing:
        - features: Tokenized and packed input sequences.
        - labels: Tokenized output sequences (identical to `outputs` from tokenizer).
    """
    outputs = tokenizer(inputs)
    features = start_packer(outputs)
    labels = outputs
    return features, labels


def prepare_and_preprocess_dataset(
    dataset: tf.data.Dataset, preprocess_fn: Callable[[tf.Tensor], Tuple[tf.Tensor, tf.Tensor]]
) -> tf.data.Dataset:
    """
    Prepares the dataset by applying preprocessing, batching, and prefetching.

    Parameters
    ----------
    dataset: tf.data.Dataset
        The raw dataset to be processed.
    preprocess_fn: callable
        The preprocessing function to be applied to the dataset.
    batch_size: int
        The size of batches to divide the dataset into.

    Returns
    -------
    tf.data.Dataset
        The processed and batched dataset.
    """
    return dataset.map(preprocess_fn, num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)


def flatten_dataset(dataset: List[Tuple[np.ndarray, np.ndarray]]) -> List[Tuple[np.ndarray, np.ndarray]]:
    """
    Flatten each pair of source and target arrays in the dataset from shape [B, L] to [B*L].

    Parameters
    ----------
    dataset : List[Tuple[np.ndarray, np.ndarray]]
        The dataset to be flattened, consisting of tuples of source and target numpy arrays.

    Returns
    -------
    List[Tuple[np.ndarray, np.ndarray]]
        The flattened dataset, where each source and target array is reshaped to [B*L].
    """
    flattened_data = [
        (source[i].reshape(-1), target[i].reshape(-1))
        for source, target in tqdm(dataset)
        for i in range(source.shape[0])
    ]
    return flattened_data


class TFDatasetWrapper(Dataset):
    def __init__(self, tf_dataset_as_numpy: List[int]) -> None:
        super().__init__()
        self.tf_dataset_as_numpy = tf_dataset_as_numpy

    def __getitem__(self, index: int) -> Tuple[torch.Tensor, torch.Tensor]:
        source, target = self.tf_dataset_as_numpy[index]

        # Convert from list to tensors
        source = torch.tensor(source, dtype=torch.long)
        target = torch.tensor(target, dtype=torch.long)
        return source, target

    def __len__(self) -> int:
        return len(self.tf_dataset_as_numpy)


def custom_collate_fn(
    batch: List[Tuple[torch.Tensor, torch.Tensor]],
) -> Tuple[torch.Tensor, torch.Tensor, torch.Tensor, torch.Tensor]:
    sources, targets = zip(*batch)

    sources = torch.stack(sources)
    targets = torch.stack(targets)

    batch_size, seq_len = targets.size(0), targets.size(1)

    future_masks = construct_dummy_batch_future_masks(batch_size, seq_len)
    target_padding_masks = construct_dummy_batch_target_padding_masks(batch_size, seq_len)

    return sources, targets, future_masks, target_padding_masks


def next(prompt: tf.Tensor, cache: Tuple[Any, ...], index: EagerTensor) -> Tuple[tf.Tensor, None, Tuple[Any, ...]]:
    prompt: NDArray[np.int32] = prompt.numpy()
    prompt: torch.LongTensor = torch.from_numpy(prompt).to(composer.trainer.device)

    index: int = int(index)
    with torch.no_grad():
        logits: torch.Tensor = model(prompt)[:, index - 1, :]
    logits: NDArray[float] = logits.detach().cpu().numpy()
    logits: tf.Tensor = tf.convert_to_tensor(logits)
    # Ignore hidden states for now; only needed for contrastive search.
    hidden_states = None
    return logits, hidden_states, cache


@torch.no_grad()
def generate_on_train_epoch_end(trainer: Trainer) -> None:
    """Evaluate and generate on train batch end."""

    import gc

    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    model = trainer.model
    model.eval()

    def get_samplers() -> List[Sampler]:
        samplers = [
            keras_nlp.samplers.GreedySampler(temperature=1.0),
            keras_nlp.samplers.BeamSampler(num_beams=10, temperature=1.0),
            keras_nlp.samplers.RandomSampler(temperature=1.0),
            keras_nlp.samplers.TopKSampler(k=10, temperature=1.0),
            keras_nlp.samplers.TopPSampler(p=0.5, temperature=1),
        ]
        return samplers

    samplers = get_samplers()
    tokenizer = trainer.state.tokenizer

    start_packer = create_start_packer(tokenizer)
    # The "packer" layers adds the [BOS] token for us.
    prompt_tokens = start_packer(tokenizer([""]))

    for sampler in samplers:
        generated_tokens = sampler(
            next=next,
            prompt=prompt_tokens,
            index=1,  # Start sampling immediately after the [BOS] token.
        )
        generated_tokens_decoded = tokenizer.detokenize(generated_tokens)
        sampler_name = sampler.__class__.__name__
        trainer.logger.info("%s search Generated text %s", sampler_name, generated_tokens_decoded)
    # Revert model to training mode
    model.train()


if __name__ == "__main__":
    download_and_extract_data(DATA_URL)
    raw_train_ds = load_and_prepare_dataset(TRAIN_FILE, BATCH_SIZE, MIN_STRING_LEN, shuffle=True)
    raw_valid_ds = load_and_prepare_dataset(VALID_FILE, BATCH_SIZE, MIN_STRING_LEN, shuffle=False)

    if COMPUTE_WORD_PIECE_VOCABULARY:
        vocabulary = keras_nlp.tokenizers.compute_word_piece_vocabulary(
            raw_train_ds,
            vocabulary_size=VOCAB_SIZE,
            lowercase=True,
            reserved_tokens=["[PAD]", "[UNK]", "[BOS]"],
        )
    #         with open(VOCABULARY_SERIALIZABLED, "wb") as f:
    #             pickle.dump(serialize_keras_object(vocabulary), f)
    else:
        vocabulary = load_vocab(VOCABULARY_SERIALIZABLED)

    tokenizer = create_tokenizer(vocabulary, SEQ_LEN)
    start_packer = create_start_packer(tokenizer)

    train_ds = prepare_and_preprocess_dataset(raw_train_ds, preprocess)
    valid_ds = prepare_and_preprocess_dataset(raw_valid_ds, preprocess)

    #     if LOAD_DATASET_FROM_PICKLE:
    #         with open(TRAIN_DATASET_PICKLED_PATH, "rb") as file:
    #             train_ds_as_list_of_numpy = pickle.load(file)

    #         with open(VALID_DATASET_PICKLED_PATH, "rb") as file:
    #             valid_ds_as_list_of_numpy = pickle.load(file)

    if SAVE_DATASET_AS_PICKLE and not LOAD_DATASET_FROM_PICKLE:
        train_ds_as_list_of_numpy = list(tfds.as_numpy(train_ds))
        valid_ds_as_list_of_numpy = list(tfds.as_numpy(valid_ds))

    #         with open(TRAIN_DATASET_PICKLED_PATH, "wb") as file:
    #             pickle.dump(train_ds_as_list_of_numpy, file)

    #         with open(VALID_DATASET_PICKLED_PATH, "wb") as file:
    #             pickle.dump(valid_ds_as_list_of_numpy, file)

    train_ds_as_numpy = flatten_dataset(train_ds_as_list_of_numpy)
    valid_ds_as_numpy = flatten_dataset(valid_ds_as_list_of_numpy)

    train_ds_pytorch = TFDatasetWrapper(train_ds_as_numpy)
    valid_ds_pytorch = TFDatasetWrapper(valid_ds_as_numpy)

    # Create a PyTorch data loader
    train_loader = DataLoader(
        train_ds_pytorch, shuffle=False, batch_size=16, collate_fn=custom_collate_fn
    )  # shuffled by tensorflow earlier
    valid_loader = DataLoader(
        valid_ds_pytorch, shuffle=False, batch_size=32, collate_fn=custom_collate_fn
    )  # shuffled by tensorflow earlier

    masked_self_attention_mha_config = MultiHeadedAttentionConfig(
        attention=ScaledDotProductAttention(), d_model=256, H=4, dropout=0.2
    )

    feed_forward_config = PositionwiseFeedForwardConfig(
        d_model=256, d_ff=256 * 4, activation=nn.GELU(approximate="tanh"), dropout=0.2, bias=True
    )

    add_norm_config_1 = AddNormConfig(feature_dim=256, dropout=0.2)
    add_norm_config_2 = AddNormConfig(feature_dim=256, dropout=0.2)

    # Create DecoderBlockConfig
    decoder_block_config = DecoderBlockConfig(
        masked_self_attention_mha=masked_self_attention_mha_config,
        feed_forward=feed_forward_config,
        add_norm_1=add_norm_config_1,
        add_norm_2=add_norm_config_2,
    )

    # Create the overall DecoderConfig
    model_config = DecoderConfig(
        d_model=256,
        vocab_size=len(vocabulary),
        context_length=SEQ_LEN,
        num_decoder_blocks=2,
        dropout=0.2,
        decoder_block=decoder_block_config,
    )

    optimizer_config_cls = OPTIMIZER_REGISTRY["torch.optim.Adam"]
    optimizer_pydantic_config = optimizer_config_cls(name="torch.optim.Adam", lr=BASE_LR * GRADIENT_ACCUMULATION_STEPS)

    criterion_config_cls = CRITERION_REGISTRY["torch.nn.CrossEntropyLoss"]
    criterion_pydantic_config = criterion_config_cls(name="torch.nn.CrossEntropyLoss")

    scheduler_config_cls = SCHEDULER_REGISTRY["torch.optim.lr_scheduler.CosineAnnealingLR"]
    scheduler_pydantic_config = scheduler_config_cls(name="torch.optim.lr_scheduler.CosineAnnealingLR", T_max=8)

    trainer_config = TrainerConfig(
        device="cuda",
        max_epochs=8,
        eval_every_n_steps=10000,
        log_every_n_steps=10000,
        use_amp=True,
        autocast_config={"enabled": True, "dtype": torch.float16, "cache_enabled": True},
        scaler_config={
            "enabled": True,
            "init_scale": 2.0**16,
            "growth_factor": 2.0,
            "backoff_factor": 0.5,
            "growth_interval": 2000,
        },
        gradient_accumulation_steps=GRADIENT_ACCUMULATION_STEPS,
        clip_grad_norm={"max_norm": 1.0, "norm_type": 2.0, "error_if_nonfinite": False, "foreach": None},
        apply_weight_decay_to_different_param_groups=False,
        step_scheduler_on_batch_or_epoch="epoch",
        save_dir="./data/simplybooks92/checkpoints",
        save_every_epoch=False,
        save_best_only=True,
        monitor="valid_this_epoch_average_loss",
        mode="min",
    )

    generator_config = GeneratorConfig(temperature=1.0, max_tokens=80, greedy=False, top_k=10, top_p=None)

    composer = Composer(
        model=model_config,
        optimizer=optimizer_pydantic_config,
        criterion=criterion_pydantic_config,
        scheduler=scheduler_pydantic_config,
        trainer=trainer_config,
        generator=generator_config,
    )
    model = GPTDecoder(model_config).to(composer.trainer.device)
    optimizer = optimizer_pydantic_config.build(params=model.parameters())
    criterion = criterion_pydantic_config.create_instance()

    composer.scheduler = scheduler_pydantic_config
    scheduler = scheduler_pydantic_config.build(optimizer=optimizer)

    composer.pretty_print()

    state = State(
        model=model,
        criterion=criterion,
        optimizer=optimizer,
        scheduler=scheduler,
        vocabulary=vocabulary,
        tokenizer=tokenizer,
    )

    device = composer.trainer.device
    trainer = Trainer(
        state=state,
        composer=composer,
        logger=None,
        device=device,  # type: ignore[arg-type]
    )
    trainer.add_callback(TrainerEvent.ON_TRAIN_EPOCH_END.value, generate_on_train_epoch_end)

    import gc

    gc.collect()
    if torch.cuda.is_available():
        torch.cuda.empty_cache()

    _trained_state = trainer.fit(train_loader=train_loader, valid_loader=valid_loader)
    # _trained_state.pretty_print()
    history = _trained_state.history
    for key in history:
        if "epoch" in key:
            print(key)
            print(history[key])

    _ = save_plot_history(history, plot=False, save_path=f"{composer.trainer.save_dir}/history.png")

    purge_global_scope(["optimizer", "state", "trainer"])
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Using TensorFlow backend
# /opt/conda/lib/python3.10/site-packages/transformers/utils/generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# Downloading data from https://dldata-public.s3.us-east-2.amazonaws.com/simplebooks.zip
# 282386239/282386239 [==============================] - 91s 0us/step
# 100%|██████████| 2445/2445 [00:00<00:00, 10090.77it/s]
# 100%|██████████| 1/1 [00:00<00:00, 8981.38it/s]
# /opt/conda/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Composer(
# │   constants=MaybeConstant(),
# │   logger=LoggerConfig(
# │   │   log_file=None,
# │   │   module_name=None,
# │   │   propagate=False,
# │   │   log_root_dir=None,
# │   │   rich_handler_config={
# │   │   │   'level': 'INFO',
# │   │   │   'console': MISSING,
# │   │   │   'show_level': True,
# │   │   │   'show_path': True,
# │   │   │   'show_time': True,
# │   │   │   'rich_tracebacks': True,
# │   │   │   'markup': True,
# │   │   │   'log_time_format': '[%Y-%m-%d %H:%M:%S]'
# │   │   }
# │   ),
# │   global_=MaybeGlobal(seed=42, debug=False, debug_samples=256),
# │   data=DataConfig(
# │   │   context_length=128,
# │   │   dataset_name=None,
# │   │   dataset_size=2,
# │   │   dataset_path=None,
# │   │   dataset_dir=None,
# │   │   dataset_url=None,
# │   │   split=[0.7, 0.1, 0.2],
# │   │   collate_fn={'batch_first': True, 'pad_token_id': 16},
# │   │   train_loader={
# │   │   │   'batch_size': 32,
# │   │   │   'shuffle': True,
# │   │   │   'num_workers': 0,
# │   │   │   'pin_memory': False,
# │   │   │   'drop_last': False
# │   │   },
# │   │   valid_loader={
# │   │   │   'batch_size': 32,
# │   │   │   'shuffle': False,
# │   │   │   'num_workers': 0,
# │   │   │   'pin_memory': False,
# │   │   │   'drop_last': False
# │   │   },
# │   │   test_loader={
# │   │   │   'batch_size': 32,
# │   │   │   'shuffle': False,
# │   │   │   'num_workers': 0,
# │   │   │   'pin_memory': False,
# │   │   │   'drop_last': False
# │   │   }
# │   ),
# │   model=DecoderConfig(
# │   │   d_model=256,
# │   │   vocab_size=4861,
# │   │   context_length=128,
# │   │   num_decoder_blocks=2,
# │   │   dropout=0.2,
# │   │   decoder_block=DecoderBlockConfig(
# │   │   │   masked_self_attention_mha=MultiHeadedAttentionConfig(
# │   │   │   │   attention=ScaledDotProductAttention(
#   (dropout): Dropout(p=0.0, inplace=False)
# ),
# │   │   │   │   d_model=256,
# │   │   │   │   H=4,
# │   │   │   │   dropout=0.2
# │   │   │   ),
# │   │   │   feed_forward=PositionwiseFeedForwardConfig(
# │   │   │   │   d_model=256,
# │   │   │   │   d_ff=1024,
# │   │   │   │   activation=GELU(approximate='tanh'),
# │   │   │   │   dropout=0.2,
# │   │   │   │   bias=True
# │   │   │   ),
# │   │   │   add_norm_1=AddNormConfig(feature_dim=256, dropout=0.2),
# │   │   │   add_norm_2=AddNormConfig(feature_dim=256, dropout=0.2)
# │   │   )
# │   ),
# │   optimizer=AdamConfig(name='torch.optim.Adam', lr=0.001, betas=(0.9, 0.98), eps=1e-09, weight_decay=0.0),
# │   criterion=CrossEntropyLossConfig(
# │   │   name='torch.nn.CrossEntropyLoss',
# │   │   weight=None,
# │   │   size_average=None,
# │   │   ignore_index=-100,
# │   │   reduction='mean',
# │   │   label_smoothing=0.0
# │   ),
# │   scheduler=CosineAnnealingLRConfig(
# │   │   name='torch.optim.lr_scheduler.CosineAnnealingLR',
# │   │   T_max=8,
# │   │   eta_min=0,
# │   │   last_epoch=-1,
# │   │   verbose=False
# │   ),
# │   trainer=TrainerConfig(
# │   │   device=device(type='cuda'),
# │   │   max_epochs=8,
# │   │   log_every_n_steps=10000,
# │   │   eval_every_n_steps=10000,
# │   │   step_scheduler_on_batch_or_epoch='epoch',
# │   │   use_amp=True,
# │   │   autocast_config={'enabled': True, 'dtype': torch.float16, 'cache_enabled': True},
# │   │   scaler_config={
# │   │   │   'enabled': True,
# │   │   │   'init_scale': 65536.0,
# │   │   │   'growth_factor': 2.0,
# │   │   │   'backoff_factor': 0.5,
# │   │   │   'growth_interval': 2000
# │   │   },
# │   │   gradient_accumulation_steps=4,
# │   │   clip_grad_norm={'max_norm': 1.0, 'norm_type': 2.0, 'error_if_nonfinite': False, 'foreach': None},
# │   │   apply_weight_decay_to_different_param_groups=False,
# │   │   save_dir='./data/simplybooks92/checkpoints/2024-02-13_15-52-36',
# │   │   save_every_epoch=False,
# │   │   save_best_only=True,
# │   │   monitor='valid_this_epoch_average_loss',
# │   │   mode='min'
# │   ),
# │   generator=GeneratorConfig(max_tokens=80, temperature=1.0, greedy=False, top_k=10, top_p=None)
# )
# 2024-02-13 15:52:36,576 - root - INFO - Initial learning rate: 0.001
# 2024-02-13 15:52:36,579 - root - INFO - Total Parameters: 4104445, Trainable Parameters: 4104445
# 2024-02-13 15:52:36,580 - root - INFO - ====================================================== Starting Train Epoch: 1/8 ======================================================
# Epoch: 1, Step: 1:   0%|          | 0/9778 [00:00<?, ?it/s, total_batch_loss=136.78937, average_batch_loss=2.13733, average_batch_perplexity=5150.63330, lr=0.001000000]/opt/conda/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:143: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
# 2024-02-13 15:57:10,225 - root - INFO - Total Samples:                   156448
# 2024-02-13 15:57:10,226 - root - INFO - Total Batches:                   9778
# 2024-02-13 15:57:10,227 - root - INFO - Average Epoch Train Loss:        4.82862
# 2024-02-13 15:57:10,228 - root - INFO - Average Epoch Train Perplexity:  125.03870
# 2024-02-13 15:57:10,229 - root - INFO -
#
# 2024-02-13 15:57:12,252 - root - INFO - GreedySampler search Generated text tf.Tensor([b'[BOS] " i have been a very much of the continuous thing , " said the confircuit of the continuous continuously . " i am sure that i have been appppppppreciation of the continuous continuous continuous continuously , and i have been appppppppppppreciation . i have been a very much of the continuous continuous continuous continuously . i have been ap'], shape=(1,), dtype=string)
# 2024-02-13 15:57:13,808 - root - INFO - BeamSampler search Generated text tf.Tensor([b'[BOS] " i don \' t know , " he said , " i don \' t know , " he said , " i don \' t know , " he said . " i don \' t tell you , " he said . " i don \' t know what i \' t know . i don \' t think i \' t tell you . i don \' t know that i \' t tell you . i don \' t know what i \' t know . i \' m going to tell you . i don \' t tell you . i \' t tell you . i \' m going to tell you . i don \' t tell you .'], shape=(1,), dtype=string)
# 2024-02-13 15:57:14,833 - root - INFO - RandomSampler search Generated text tf.Tensor([b'[BOS] " suppose were quite twenty - one of this was had already been killed it . " this is a child of the dining - room . she and i will go back to you will be the widower ? " but did all about twelve parts , fames " as the bury , leaving her mamma tong was until the doctor was opened , " announced she said : the phfer brussels girls . 5 , and in any day those who had a common naturedople of each school . i know if she did not spend this place . when it comes to decision to bring pulchar'], shape=(1,), dtype=string)
# 2024-02-13 15:57:15,882 - root - INFO - TopKSampler search Generated text tf.Tensor([b'[BOS] the two knights went into the country . the two others were at the same time . they saw that they were in the midst of the forest , and he knew what he could do . he knew it was quite true that the man of his son would be a controidered with a few men . the confounding and his horse and he could not see a man . it was a little old man , but the man was a man who had a great deal of the chattering , and his eyes of the bocommend , the men , who was not apppre'], shape=(1,), dtype=string)
# 2024-02-13 15:57:17,292 - root - INFO - TopPSampler search Generated text tf.Tensor([b'[BOS] " i am not having to do it ; " said the only thing i \' m going to do this , " said he " and i think you are at least a few hours , but i have got into it , and the first thing i have to find it to see the world , but i don \' t tell you about it . i don \' t think you are very glad to take the day , i \' m going to get up to bed . i am sure that i \' m going to get out and i can do . you are not so we must know what i \' m going to say . i have been born'], shape=(1,), dtype=string)
# 2024-02-13 15:57:17,294 - root - INFO - ====================================================== Starting Valid Epoch: 1/8 ======================================================
# 2024-02-13 15:57:17,406 - root - INFO - Saved checkpoint at epoch 1 to ./data/simplybooks92/checkpoints/2024-02-13_15-52-36/model_checkpoint_epoch_1.pt
# 2024-02-13 15:57:17,408 - root - INFO - Total Samples:                   11
# 2024-02-13 15:57:17,409 - root - INFO - Total Batches:                   1
# 2024-02-13 15:57:17,410 - root - INFO - Average Epoch Valid Loss:        4.33138
# 2024-02-13 15:57:17,410 - root - INFO - Average Epoch Valid Perplexity:  76.04945
# 2024-02-13 15:57:17,411 - root - INFO -
#
# 2024-02-13 15:57:17,413 - root - INFO - ====================================================== Starting Train Epoch: 2/8 ======================================================
# Epoch: 2, Step: 221:   2%|▏         | 220/9778 [00:06<04:24, 36.20it/s, total_batch_loss=74.24950, average_batch_loss=1.16015, average_batch_perplexity=103.60909, lr=0.000853553]2024-02-13 15:57:23,599 - root - INFO - Epoch: 2, Step: 10000, Avg Batch Loss: 1.12628, Avg Batch Perplexity: 90.36945, LR: 0.000961940
# 2024-02-13 16:01:51,842 - root - INFO - Total Samples:                   156448
# 2024-02-13 16:01:51,842 - root - INFO - Total Batches:                   9778
# 2024-02-13 16:01:51,843 - root - INFO - Average Epoch Train Loss:        4.39668
# 2024-02-13 16:01:51,844 - root - INFO - Average Epoch Train Perplexity:  81.18112
# 2024-02-13 16:01:51,845 - root - INFO -
#
# 2024-02-13 16:01:53,079 - root - INFO - GreedySampler search Generated text tf.Tensor([b'[BOS] " i have been a very good deal of the world , " said the old man . " i have been a very good deal of trouble . i have been a very good deal of trouble . i have been a very good deal of trouble , and i have been able to make a good deal of trouble . i have been a very good deal of trouble , and i have been able to get a lot of money . i have been a lot of money , and i have been a good deal of money . i have been a lot of money , and i have been a good deal of money . i have been a lot of money'], shape=(1,), dtype=string)
# 2024-02-13 16:01:54,447 - root - INFO - BeamSampler search Generated text tf.Tensor([b'[BOS] " i don \' t know , " he said . " i don \' t know what i am going to do , " he said . " i don \' t know what i am going to do . i don \' t know what i am going to do . i don \' t know what i am going to do . i don \' t know what i am going to do . i don \' t know what i am going to do . i don \' t know what i am going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do .'], shape=(1,), dtype=string)
# 2024-02-13 16:01:55,481 - root - INFO - RandomSampler search Generated text tf.Tensor([b"[BOS] returning quietly away with her majesty , and took the cart of armor of the aid of it with her majesty that she did not seem to be closed with induchs , but for her days she had taken from her majesty ' s order ; knowing however , which she did change themselves for their degree by nature quite barely as the difecified her majesty , or was rarely delivered by a side of sea , or stephen to those sickening power as i could speak . in the night mind of the library , who or to study a little one whom was masters dismographed to a bold"], shape=(1,), dtype=string)
# 2024-02-13 16:01:56,527 - root - INFO - TopKSampler search Generated text tf.Tensor([b'[BOS] after this a time the old man had been left in his hand , and the conflicted with the transformer of the conflictions to the proficiencing him with the proposal of a thronze to the proportion of the fugitive substance , who , he was very discontented in acussion . this was not interview with anticipated . aclamation of disorder , but admirable , he would be accurately declined , he resolved to con'], shape=(1,), dtype=string)
# 2024-02-13 16:01:57,899 - root - INFO - TopPSampler search Generated text tf.Tensor([b"[BOS] as i spoke of the young men - - the young fellow - - boy is a bad man . he has got his hair , and he would have been tempted to give the matter . it was his name was not at all ; and i ' ve got up in his head and put his neck in his mouth . he was a big twigs at the same time , and he didn ' t know that he was so many of the best , and he was . i don ' t know him that he didn ' t see anything but what a big world . he was afraid he would be afraid of the world . he"], shape=(1,), dtype=string)
# 2024-02-13 16:01:57,901 - root - INFO - ====================================================== Starting Valid Epoch: 2/8 ======================================================
# 2024-02-13 16:01:58,004 - root - INFO - Saved checkpoint at epoch 2 to ./data/simplybooks92/checkpoints/2024-02-13_15-52-36/model_checkpoint_epoch_2.pt
# 2024-02-13 16:01:58,005 - root - INFO - Total Samples:                   11
# 2024-02-13 16:01:58,005 - root - INFO - Total Batches:                   1
# 2024-02-13 16:01:58,006 - root - INFO - Average Epoch Valid Loss:        4.15610
# 2024-02-13 16:01:58,007 - root - INFO - Average Epoch Valid Perplexity:  63.82233
# 2024-02-13 16:01:58,007 - root - INFO -
#
# 2024-02-13 16:01:58,009 - root - INFO - ====================================================== Starting Train Epoch: 3/8 ======================================================
# Epoch: 3, Step: 443:   4%|▍         | 440/9778 [00:12<04:18, 36.07it/s, total_batch_loss=70.73589, average_batch_loss=1.10525, average_batch_perplexity=83.25224, lr=0.000853553]2024-02-13 16:02:10,362 - root - INFO - Epoch: 3, Step: 20000, Avg Batch Loss: 1.04869, Avg Batch Perplexity: 66.37447, LR: 0.000961940
# 2024-02-13 16:06:30,531 - root - INFO - Total Samples:                   156448
# 2024-02-13 16:06:30,531 - root - INFO - Total Batches:                   9778
# 2024-02-13 16:06:30,532 - root - INFO - Average Epoch Train Loss:        4.27876
# 2024-02-13 16:06:30,533 - root - INFO - Average Epoch Train Perplexity:  72.15102
# 2024-02-13 16:06:30,534 - root - INFO -
#
# 2024-02-13 16:06:31,740 - root - INFO - GreedySampler search Generated text tf.Tensor([b'[BOS] " i have been a very good deal of trouble , " said the old man . " i have been a very good deal of trouble . i have been a good deal of trouble , and i have been a good deal of trouble . i have been a good deal of trouble , and i have been a good deal of trouble . i have been a good deal of trouble , and i have been a good deal of trouble . i have been a lot of trouble , and i have been a lot of trouble . i have been a lot of trouble to be a lot of trouble . i have been a lot of trouble to be a lot'], shape=(1,), dtype=string)
# 2024-02-13 16:06:33,072 - root - INFO - BeamSampler search Generated text tf.Tensor([b'[BOS] " i don \' t know , " he said . " i don \' t know what i can do , " he said . " i don \' t know what i have to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to'], shape=(1,), dtype=string)
# 2024-02-13 16:06:34,182 - root - INFO - RandomSampler search Generated text tf.Tensor([b'[BOS] as he scored those who are having been attached to a general opinion of any other ; but the men are small wives of the grandest the great divided from their backs overwhelms , and tovations . perhaps the general of migariah amien , it certainly . the extremes of carthage , not that came here , but to push without a relative consent , and have escaped from a recent ten years , besides , cultiquerable poodles of importance , proved grief to prefer to occcuprehen , and to distinguish the'], shape=(1,), dtype=string)
# 2024-02-13 16:06:35,225 - root - INFO - TopKSampler search Generated text tf.Tensor([b'[BOS] there was no reason to be the convention to be sent to the principal . this was , of course it was necessary to take the politics . the compariations of the men , who had taken the opportunity for his services , had taken in the matter of this expedition . the men had been killed and the english officer of the enemy . the news of their own officers were ordered to join their men . this had been reported that some men could be killed in the battlefield . these were killed in the french and killed and wounded men . the french had been engaged . the french cavalry were in'], shape=(1,), dtype=string)
# 2024-02-13 16:06:36,560 - root - INFO - TopPSampler search Generated text tf.Tensor([b'[BOS] " it \' s no more than to be expected , " said miss laurelley , with a hinthly exhibition of a series of speeches , " as a harveyor . " i suppose the difference between the two conventions , of the more fascination , and commissions in the present instance of the city , we have made a genial conquent of a number of bronze of sands . we are fond of continent , the captain of a boat , and i will go down on the deck of the s'], shape=(1,), dtype=string)
# 2024-02-13 16:06:36,562 - root - INFO - ====================================================== Starting Valid Epoch: 3/8 ======================================================
# 2024-02-13 16:06:36,665 - root - INFO - Saved checkpoint at epoch 3 to ./data/simplybooks92/checkpoints/2024-02-13_15-52-36/model_checkpoint_epoch_3.pt
# 2024-02-13 16:06:36,666 - root - INFO - Total Samples:                   11
# 2024-02-13 16:06:36,667 - root - INFO - Total Batches:                   1
# 2024-02-13 16:06:36,668 - root - INFO - Average Epoch Valid Loss:        4.08236
# 2024-02-13 16:06:36,668 - root - INFO - Average Epoch Valid Perplexity:  59.28546
# 2024-02-13 16:06:36,669 - root - INFO -
#
# 2024-02-13 16:06:36,670 - root - INFO - ====================================================== Starting Train Epoch: 4/8 ======================================================
# Epoch: 4, Step: 665:   7%|▋         | 664/9778 [00:18<04:14, 35.81it/s, total_batch_loss=70.64276, average_batch_loss=1.10379, average_batch_perplexity=82.60437, lr=0.000853553]2024-02-13 16:06:55,186 - root - INFO - Epoch: 4, Step: 30000, Avg Batch Loss: 1.05251, Avg Batch Perplexity: 67.41972, LR: 0.000961940
# 2024-02-13 16:11:09,381 - root - INFO - Total Samples:                   156448
# 2024-02-13 16:11:09,382 - root - INFO - Total Batches:                   9778
# 2024-02-13 16:11:09,383 - root - INFO - Average Epoch Train Loss:        4.21576
# 2024-02-13 16:11:09,383 - root - INFO - Average Epoch Train Perplexity:  67.74532
# 2024-02-13 16:11:09,385 - root - INFO -
#
# 2024-02-13 16:11:10,635 - root - INFO - GreedySampler search Generated text tf.Tensor([b'[BOS] " i don \' t know what i can do , " said the old man . " i have been a very good deal of trouble . i have been a man , and i have been a man , and i have been a man of the same age . i have been a man , and i have been a man , and i have been a man . i have been a man , and i have been a man , and i have been a man , and i have been a man . i have been a man , and i have been a man , and i have been a man , and i have been a man . i'], shape=(1,), dtype=string)
# 2024-02-13 16:11:12,150 - root - INFO - BeamSampler search Generated text tf.Tensor([b'[BOS] " i don \' t know , " he said . " i don \' t know what i am going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do'], shape=(1,), dtype=string)
# 2024-02-13 16:11:13,202 - root - INFO - RandomSampler search Generated text tf.Tensor([b"[BOS] william grove came so rapidly that they burst , not knowing that unless he wished to be recall , without attacking him on a dull day ' journey . they were much excited to proceed , then , finding the men . then he the old woman with her , slow rivalry and composition concluded to take charge of the school , beyond the blame . a easily interested indian the boys who were in know his respect - - the words . but bishop connraine was there was just to have helped him to speak , and although retiring for his chief tarritory rejoined to det"], shape=(1,), dtype=string)
# 2024-02-13 16:11:14,261 - root - INFO - TopKSampler search Generated text tf.Tensor([b'[BOS] " yes , i can get a lot of trouble with my father . i have to give me a lot of money , " he replied . " the boys were to work and i guess i was a very nice place , as they did when i came into the house . i asked her to make the best of it . i didn \' t know that . i wouldn \' t tell him anything but i \' m going on for a while i told me about it . i told him the old man who has been so many years ago , but i had told him that i was in my place ; he wouldn \' t get him . i'], shape=(1,), dtype=string)
# 2024-02-13 16:11:15,623 - root - INFO - TopPSampler search Generated text tf.Tensor([b"[BOS] the people did not know what was done . the old man said he was just as fond of the place of the farmer brown ' s boy . but when he was afraid he could make the difference between them and the old - fashioned lincolnounge and make the way out of the hill . the prince , however , he had just come to the spot where he had expected . he had a chance to know where he had taken the boy had taken a treatench - to be off , but he did not want to go on board . it was the first time he was a very strong enough to"], shape=(1,), dtype=string)
# 2024-02-13 16:11:15,625 - root - INFO - ====================================================== Starting Valid Epoch: 4/8 ======================================================
# 2024-02-13 16:11:15,728 - root - INFO - Saved checkpoint at epoch 4 to ./data/simplybooks92/checkpoints/2024-02-13_15-52-36/model_checkpoint_epoch_4.pt
# 2024-02-13 16:11:15,729 - root - INFO - Total Samples:                   11
# 2024-02-13 16:11:15,730 - root - INFO - Total Batches:                   1
# 2024-02-13 16:11:15,731 - root - INFO - Average Epoch Valid Loss:        4.04299
# 2024-02-13 16:11:15,731 - root - INFO - Average Epoch Valid Perplexity:  56.99649
# 2024-02-13 16:11:15,733 - root - INFO -
#
# 2024-02-13 16:11:15,733 - root - INFO - ====================================================== Starting Train Epoch: 5/8 ======================================================
# Epoch: 5, Step: 887:   9%|▉         | 884/9778 [00:24<04:11, 35.37it/s, total_batch_loss=68.91853, average_batch_loss=1.07685, average_batch_perplexity=74.33588, lr=0.000853553]2024-02-13 16:11:40,437 - root - INFO - Epoch: 5, Step: 40000, Avg Batch Loss: 1.08822, Avg Batch Perplexity: 77.59962, LR: 0.000961940
# 2024-02-13 16:15:50,402 - root - INFO - Total Samples:                   156448
# 2024-02-13 16:15:50,403 - root - INFO - Total Batches:                   9778
# 2024-02-13 16:15:50,404 - root - INFO - Average Epoch Train Loss:        4.17393
# 2024-02-13 16:15:50,406 - root - INFO - Average Epoch Train Perplexity:  64.97026
# 2024-02-13 16:15:50,406 - root - INFO -
#
# 2024-02-13 16:15:51,695 - root - INFO - GreedySampler search Generated text tf.Tensor([b'[BOS] " i don \' t know what i can do , " said the old man . " i \' m not going to be a man , but i \' m not going to be a man . i \' m going to be a man , and i \' m going to be a man . i \' m going to be a man , and i \' m going to be a man . i \' m going to be a man , and i \' m going to be a man . i \' m going to be a man , and i \' m going to be a man . i \' m going to be a man , and i \''], shape=(1,), dtype=string)
# 2024-02-13 16:15:53,087 - root - INFO - BeamSampler search Generated text tf.Tensor([b'[BOS] " i don \' t know , " she said . " i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to'], shape=(1,), dtype=string)
# 2024-02-13 16:15:54,123 - root - INFO - RandomSampler search Generated text tf.Tensor([b"[BOS] there was no fine - fashioned refined tins on which they were to float on one side . so that by this time the owner had driven notice of it known almost into khanging vickensington ' s notice . he was informed of his belongings he had not experienced enough for a few days ,fs . yet , there was no words . he felt that the dates ( his prayers followed by the times ) he wore , 000 pecities , when he cast his large eyed face in his heart , activity with much caution . he was an experience of impatientious consequence , thought it"], shape=(1,), dtype=string)
# 2024-02-13 16:15:55,371 - root - INFO - TopKSampler search Generated text tf.Tensor([b"[BOS] the old man went away to the edge of the hill , and there he had been so much excitement that he might go . he had not heard that the old man ' s wife would not have the least difficulty in doing so . he had learned that the first time he had been so long to see him . he was very fond of doing something in a way , and he thought that a man would come to the house he had a chance . but when the old man came down to the ground , he was sure that they would be so tired that he would go back to sleep and wait until the sun began to grow hot when he"], shape=(1,), dtype=string)
# 2024-02-13 16:15:56,761 - root - INFO - TopPSampler search Generated text tf.Tensor([b'[BOS] " the monday of a man is about the sort of old house , " said miss harris . " i am afraid it will be my duty to do as well as to the war . we have two sons , and have already begun to be over here , and you will find the estates . i have been ordered to take the electrons , and the conquerors are in connection with the girls , and i will take the rebellion , if you are better official , i should have the opportunity of making it . it is that i can tell you that the i'], shape=(1,), dtype=string)
# 2024-02-13 16:15:56,763 - root - INFO - ====================================================== Starting Valid Epoch: 5/8 ======================================================
# 2024-02-13 16:15:56,872 - root - INFO - Saved checkpoint at epoch 5 to ./data/simplybooks92/checkpoints/2024-02-13_15-52-36/model_checkpoint_epoch_5.pt
# 2024-02-13 16:15:56,873 - root - INFO - Total Samples:                   11
# 2024-02-13 16:15:56,874 - root - INFO - Total Batches:                   1
# 2024-02-13 16:15:56,875 - root - INFO - Average Epoch Valid Loss:        4.01590
# 2024-02-13 16:15:56,875 - root - INFO - Average Epoch Valid Perplexity:  55.47310
# 2024-02-13 16:15:56,876 - root - INFO -
#
# 2024-02-13 16:15:56,878 - root - INFO - ====================================================== Starting Train Epoch: 6/8 ======================================================
# Epoch: 6, Step: 1109:  11%|█▏        | 1108/9778 [00:31<04:05, 35.31it/s, total_batch_loss=62.00539, average_batch_loss=0.96883, average_batch_perplexity=48.18270, lr=0.000853553]2024-02-13 16:16:28,204 - root - INFO - Epoch: 6, Step: 50000, Avg Batch Loss: 0.93316, Avg Batch Perplexity: 41.78017, LR: 0.000961940
# 2024-02-13 16:20:32,174 - root - INFO - Total Samples:                   156448
# 2024-02-13 16:20:32,175 - root - INFO - Total Batches:                   9778
# 2024-02-13 16:20:32,176 - root - INFO - Average Epoch Train Loss:        4.14287
# 2024-02-13 16:20:32,177 - root - INFO - Average Epoch Train Perplexity:  62.98353
# 2024-02-13 16:20:32,177 - root - INFO -
#
# 2024-02-13 16:20:33,394 - root - INFO - GreedySampler search Generated text tf.Tensor([b'[BOS] " i don \' t know what i can do , " said the old man . " i don \' t know what i can do . i don \' t know what i can do . i don \' t know what i can do . i don \' t know what i can do . i don \' t know what i can do . i don \' t know what i can do . i don \' t know what i can do . i don \' t know what i can do . i don \' t know what i \' m going to do . i \' m going to be a good deal of trouble . i \' m going'], shape=(1,), dtype=string)
# 2024-02-13 16:20:34,795 - root - INFO - BeamSampler search Generated text tf.Tensor([b'[BOS] " i don \' t know , " she said . " i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to'], shape=(1,), dtype=string)
# 2024-02-13 16:20:35,854 - root - INFO - RandomSampler search Generated text tf.Tensor([b'[BOS] after the firing at which they rested in spreading out upon their shot , suddenly angry shouts of thunder , and when the shrill took a musket of kindly man , despite the shape of study , they made cautiously till reurf began to dive on by means of hide where they had been left on made of a proposal , delug before daybreak ; as the second house on which were to cut through the enemy . the alarm - battle was erect to the enemy , and held them to his assistance there was no possibility of being more chased ; after he reached the ground , to chance obviously'], shape=(1,), dtype=string)
# 2024-02-13 16:20:36,969 - root - INFO - TopKSampler search Generated text tf.Tensor([b"[BOS] the commendained to compliment and concealment to the corps of the french troops , who had been in charge of the portuguese , and had been engaged in the french , were captured by their number of troops , and , after the war , they had been captured by the english army , but in vain . these was in the fight , but the british , as the enemy , had been engaged . the latter , who was to be in command of the french , and that they should march , had a very short distance in the enemy ' s bay , in the french lines , and"], shape=(1,), dtype=string)
# 2024-02-13 16:20:38,471 - root - INFO - TopPSampler search Generated text tf.Tensor([b'[BOS] a few days later , when the battle was fought , the southern troops were on the 24th of june , the french were brought up to them , but the position of the british position was strongly fortified . the spancatural position was composed of english , and the whole line of the spanish lines of the front line . the latter , however , was more than half - an hour later , the french general division . the guns were lined with orders that the french army was not yet entrenched , but a second line of the enemy . the french had , in spite of the cavalry and french ,'], shape=(1,), dtype=string)
# 2024-02-13 16:20:38,475 - root - INFO - ====================================================== Starting Valid Epoch: 6/8 ======================================================
# 2024-02-13 16:20:38,585 - root - INFO - Saved checkpoint at epoch 6 to ./data/simplybooks92/checkpoints/2024-02-13_15-52-36/model_checkpoint_epoch_6.pt
# 2024-02-13 16:20:38,586 - root - INFO - Total Samples:                   11
# 2024-02-13 16:20:38,587 - root - INFO - Total Batches:                   1
# 2024-02-13 16:20:38,587 - root - INFO - Average Epoch Valid Loss:        3.97874
# 2024-02-13 16:20:38,588 - root - INFO - Average Epoch Valid Perplexity:  53.44949
# 2024-02-13 16:20:38,589 - root - INFO -
#
# 2024-02-13 16:20:38,590 - root - INFO - ====================================================== Starting Train Epoch: 7/8 ======================================================
# Epoch: 7, Step: 1331:  14%|█▎        | 1328/9778 [00:37<03:58, 35.41it/s, total_batch_loss=70.50316, average_batch_loss=1.10161, average_batch_perplexity=inf, lr=0.000853553]     2024-02-13 16:21:16,139 - root - INFO - Epoch: 7, Step: 60000, Avg Batch Loss: 1.08599, Avg Batch Perplexity: 76.99574, LR: 0.000961940
# 2024-02-13 16:25:14,964 - root - INFO - Total Samples:                   156448
# 2024-02-13 16:25:14,965 - root - INFO - Total Batches:                   9778
# 2024-02-13 16:25:14,966 - root - INFO - Average Epoch Train Loss:        4.11931
# 2024-02-13 16:25:14,967 - root - INFO - Average Epoch Train Perplexity:  61.51648
# 2024-02-13 16:25:14,968 - root - INFO -
#
# 2024-02-13 16:25:16,307 - root - INFO - GreedySampler search Generated text tf.Tensor([b'[BOS] " i don \' t know what i can do , " said the old man . " i \' ve been a man , and i \' m not going to be a man , but i \' m not going to be a man . i \' m going to be a man , and i \' m going to be a man , and i \' m going to be a man , and i \' m going to be a man , and i \' m going to be a man , and i \' m going to be a man , and i \' m going to be a man , and i \' m going to be a man , and'], shape=(1,), dtype=string)
# 2024-02-13 16:25:17,793 - root - INFO - BeamSampler search Generated text tf.Tensor([b'[BOS] " i don \' t know what i \' m going to do , " he said . " i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t'], shape=(1,), dtype=string)
# 2024-02-13 16:25:18,935 - root - INFO - RandomSampler search Generated text tf.Tensor([b'[BOS] as we were executed , there were but one spot on the head of it , displeased before the reciples and was a splendid sight . no one of these hideous streets was visible , a carpet of meadow , and was often performed with their number . one was the while the statre in the struggle was uttering shouts of energy and agony . the band liked together they were with redness , those of upper classes , for they had put their heads . the former looked puzzled , miss disliker , whom they had had done as theyid done ; and could not help being'], shape=(1,), dtype=string)
# 2024-02-13 16:25:20,116 - root - INFO - TopKSampler search Generated text tf.Tensor([b'[BOS] the first day after the departure of the expedition , mr . carson and his party were ordered to leave the fort at the fort . the garrison consisted of twenty , and the second lieutenant of the second lieutenant and two guns were in the afternoon , as the french commander of the garrison , who , with a great number of the enemy invaders , had been killed . as the latter had been sent forward with them , the troops were now at a time , and the men , at which the garrison had been taken , and the french were placed in the rear . the french had now fallen down , and the enemy would have gone .'], shape=(1,), dtype=string)
# 2024-02-13 16:25:21,829 - root - INFO - TopPSampler search Generated text tf.Tensor([b'[BOS] the three girls were waiting to watch for the dance . the lads were waiting for the new school . a half - holiday party , one of the party were waiting for the girls . the following morning the boys entered the dining room . it was the scene , and when the two girls entered the room , they began to show themselves what they had made up their minds . the boys went to school , and to the little girl , and the girls in a very good way . the two girls were ready to start . they were not tired of the schoolroom . the chatterer , however , and the first mate had gone , but'], shape=(1,), dtype=string)
# 2024-02-13 16:25:21,831 - root - INFO - ====================================================== Starting Valid Epoch: 7/8 ======================================================
# 2024-02-13 16:25:21,937 - root - INFO - Saved checkpoint at epoch 7 to ./data/simplybooks92/checkpoints/2024-02-13_15-52-36/model_checkpoint_epoch_7.pt
# 2024-02-13 16:25:21,938 - root - INFO - Total Samples:                   11
# 2024-02-13 16:25:21,939 - root - INFO - Total Batches:                   1
# 2024-02-13 16:25:21,940 - root - INFO - Average Epoch Valid Loss:        3.96861
# 2024-02-13 16:25:21,941 - root - INFO - Average Epoch Valid Perplexity:  52.91092
# 2024-02-13 16:25:21,942 - root - INFO -
#
# 2024-02-13 16:25:21,942 - root - INFO - ====================================================== Starting Train Epoch: 8/8 ======================================================
# Epoch: 8, Step: 1553:  16%|█▌        | 1552/9778 [00:44<03:54, 35.11it/s, total_batch_loss=67.08192, average_batch_loss=1.04815, average_batch_perplexity=66.11570, lr=0.000853553]2024-02-13 16:26:06,319 - root - INFO - Epoch: 8, Step: 70000, Avg Batch Loss: 1.04936, Avg Batch Perplexity: 66.63425, LR: 0.000961940
# 2024-02-13 16:29:57,737 - root - INFO - Total Samples:                   156448
# 2024-02-13 16:29:57,737 - root - INFO - Total Batches:                   9778
# 2024-02-13 16:29:57,738 - root - INFO - Average Epoch Train Loss:        4.10067
# 2024-02-13 16:29:57,739 - root - INFO - Average Epoch Train Perplexity:  60.38052
# 2024-02-13 16:29:57,739 - root - INFO -
#
# 2024-02-13 16:29:58,960 - root - INFO - GreedySampler search Generated text tf.Tensor([b'[BOS] " i don \' t know what i can do , " said the old man . " i \' m not going to be a man , but i \' m not going to be a man . i \' m going to be a man , and i \' m going to be a man . i \' m going to be a man , and i \' m going to be a man . i \' m going to be a man , and i \' m going to be a man , and i \' m going to be a man , and i \' m going to be a man , and i \' m going to be a man . i'], shape=(1,), dtype=string)
# 2024-02-13 16:30:00,337 - root - INFO - BeamSampler search Generated text tf.Tensor([b'[BOS] " i don \' t know what i can do , " he said . " i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do , but i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t know what i \' m going to do . i don \' t want to'], shape=(1,), dtype=string)
# 2024-02-13 16:30:01,355 - root - INFO - RandomSampler search Generated text tf.Tensor([b"[BOS] i have had caused rather serious talk to this household . the boys made their minds appear in bedding her affairs , in the year or day or so young girls had eventually invited them to visit extremely a part of the winter which dr . harmoniated them to enjoy them . but unfortunately she pleased them , i have inlour and regret at the ease of such tyrants , on telling of the particular business to do much . canyson ' s view over the pleasant talk , though she was very anxious to read of doubts . some object between the hinthummings that were not more than done"], shape=(1,), dtype=string)
# 2024-02-13 16:30:02,440 - root - INFO - TopKSampler search Generated text tf.Tensor([b'[BOS] the first day was , but it was evident that it was a strange thing to do to tell , in a state of excitement , that he was in command of mr . gilbert . m . bruce was in his place in the field , and it was a very short time ago , to the caliquet , but the other boys did not look at the comparation . he felt that the commodox was one . he would have been a great one , and he would have been very much surprised to find it . he had not heard the sound of the voice in his voice in'], shape=(1,), dtype=string)
# 2024-02-13 16:30:03,906 - root - INFO - TopPSampler search Generated text tf.Tensor([b'[BOS] when the chalk had finished their breakfast , and their new breakfast was finished . it was soon decided that it was all done . the two boats had been washed away . they had to go in the afternoon . the men were at work . they went on with them . the first day they came to the room , where they had been sitting on the floor , they were standing on the table , and looked at the deck . then they said they had gone away . the men went to the cabin and looked as if they were safe . they were just as they were in the cabin . they went up and down on the top of'], shape=(1,), dtype=string)
# 2024-02-13 16:30:03,908 - root - INFO - ====================================================== Starting Valid Epoch: 8/8 ======================================================
# 2024-02-13 16:30:04,033 - root - INFO - Saved checkpoint at epoch 8 to ./data/simplybooks92/checkpoints/2024-02-13_15-52-36/model_checkpoint_epoch_8.pt
# 2024-02-13 16:30:04,034 - root - INFO - Total Samples:                   11
# 2024-02-13 16:30:04,035 - root - INFO - Total Batches:                   1
# 2024-02-13 16:30:04,036 - root - INFO - Average Epoch Valid Loss:        3.94326
# 2024-02-13 16:30:04,036 - root - INFO - Average Epoch Valid Perplexity:  51.58647
# 2024-02-13 16:30:04,037 - root - INFO -
# train_this_epoch_average_loss
# [4.828623116686925, 4.396682687077841, 4.278761493791513, 4.215755564885091, 4.17392971352776, 4.142873145998024, 4.119305330128435, 4.1006666644264715]
# train_this_epoch_average_perplexity
# [125.03870391845703, 81.18112182617188, 72.15101623535156, 67.74532318115234, 64.97026062011719, 62.9835319519043, 61.516483306884766, 60.38051986694336]
# valid_this_epoch_average_loss
# [4.33138370513916, 4.156103134155273, 4.082364082336426, 4.042989730834961, 4.01589822769165, 3.9787371158599854, 3.9686098098754883, 3.9432594776153564]
# valid_this_epoch_average_perplexity
# [76.04944610595703, 63.822330474853516, 59.28546142578125, 56.99649429321289, 55.47309875488281, 53.44948959350586, 52.91092300415039, 51.58647155761719]

# %% [markdown]
# ## Inference/Generation

# %%
from omnivault.utils.reproducibility.seed import seed_all
import tensorflow as tf

seed_all()
tf.random.set_seed(1992)
# Out:
# /kaggle/working/omniverse/omnivault/transformer/utils/reproducibility.py:69: UserWarning: Deterministic mode is activated. This will negatively impact performance and may cause increase in CUDA memory footprint.
#   configure_deterministic_mode()

# %%
model.eval()  # important!

# The "packer" layers adds the [BOS] token for us.
prompt_tokens = start_packer(tokenizer([""]))
prompt_tokens


def next(prompt, cache, index):
    prompt = prompt.numpy()
    prompt = torch.from_numpy(prompt).to(composer.trainer.device)
    #     print(prompt)
    #     print(prompt.shape)
    #     print(model(prompt))
    #     print(index)

    index = int(index)
    with torch.no_grad():
        logits = model(prompt)[:, index - 1, :]
    logits = logits.detach().cpu().numpy()
    logits = tf.convert_to_tensor(logits)
    # Ignore hidden states for now; only needed for contrastive search.
    hidden_states = None
    return logits, hidden_states, cache

# %%
sampler = keras_nlp.samplers.GreedySampler()
output_tokens = sampler(
    next=next,
    prompt=prompt_tokens,
    index=1,  # Start sampling immediately after the [BOS] token.
)
txt = tokenizer.detokenize(output_tokens)
print(f"Greedy search generated text: \n{txt}\n")
# Out:
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/linear.py:116: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#cublasApi_reproducibility (Triggered internally at ../aten/src/ATen/Context.cpp:164.)
#   return F.linear(input, self.weight, self.bias)
# /kaggle/working/omniverse/omnivault/transformer/modules/attention/core.py:248: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#cublasApi_reproducibility (Triggered internally at ../aten/src/ATen/Context.cpp:164.)
#   attention_scores  = torch.matmul(query, key.transpose(dim0=-2, dim1=-1)) / torch.sqrt(torch.tensor(d_q).float())
# /kaggle/working/omniverse/omnivault/transformer/modules/attention/core.py:254: UserWarning: Deterministic behavior was enabled with either `torch.use_deterministic_algorithms(True)` or `at::Context::setDeterministicAlgorithms(true)`, but this operation is not deterministic because it uses CuBLAS and you have CUDA >= 10.2. To enable deterministic behavior in this case, you must set an environment variable before running your PyTorch application: CUBLAS_WORKSPACE_CONFIG=:4096:8 or CUBLAS_WORKSPACE_CONFIG=:16:8. For more information, go to https://docs.nvidia.com/cuda/cublas/index.html#cublasApi_reproducibility (Triggered internally at ../aten/src/ATen/Context.cpp:164.)
#   context_vector    = torch.matmul(attention_weights, value)
# Greedy search generated text:
# [b'[BOS] " i don \' t know what i can do , " said the old man . " i \' m not going to be a man , but i \' m not going to be a man . i \' m going to be a man , and i \' m going to be a man . i \' m going to be a man , and i \' m going to be a man . i \' m going to be a man , and i \' m going to be a man , and i \' m going to be a man , and i \' m going to be a man , and i \' m going to be a man . i']

# %%
sampler = keras_nlp.samplers.TopKSampler(k=10)
output_tokens = sampler(
    next=next,
    prompt=prompt_tokens,
    index=1,
)
txt = tokenizer.detokenize(output_tokens)
print(f"Top-K search generated text: \n{txt}\n")
# Out:
# Top-K search generated text:
# [b'[BOS] the sun shone brightly and warm and the sun shone brighter at the sky , but the sun was full of joy , and all at the heavens were shining and sweet . there were the heavenly shining stars . the sun shone bright stars , blue sky shone over it with bright green stars , brighter shining stars and the stars shone brighter the rays of the heavens , all the heaven of the stars were shining bright blue , the heavenly blue sky - bright sky shone as silver stars . all the sky shone and white with bright green clouds in her bright blue sky as the sky sky , as she gazed . it was']

# %%
sampler = keras_nlp.samplers.TopPSampler(p=0.5)
output_tokens = sampler(
    next=next,
    prompt=prompt_tokens,
    index=1,
)
txt = tokenizer.detokenize(output_tokens)
print(f"Top-P search generated text: \n{txt}\n")
# Out:
# Top-P search generated text:
# [b'[BOS] the boys did not know what they had , but they were going to meet the next day . the weather was very fine , and the old weather was hard , and so as to chatterer the sea was in the ocean . the sea was full of water , and the stars were flowing with gliding and multitudes of snow , and sometimes the waves were flowing from the shore . the wind was blowing up in the water , and the wind blowing up the sails . they were at the bottom of the water and the sea to the waves were foaming over the waves . the sea was rising in the']

# %% [markdown]
# ## Train and Serialize Keras's Word Piece Vocabulary

# %%
# # Train tokenizer vocabulary
# vocab = keras_nlp.tokenizers.compute_word_piece_vocabulary(
#     raw_train_ds,
#     vocabulary_size=VOCAB_SIZE,
#     lowercase=True,
#     reserved_tokens=["[PAD]", "[UNK]", "[BOS]"],
# )

# %%
# import pickle

# # Assume `vocab` is your vocabulary object
# with open('vocabulary.pkl', 'wb') as f:
#     pickle.dump(vocab, f)

# %%
# from keras.saving import serialize_keras_object
# from keras.layers import Dense

# vocab_obj = serialize_keras_object(vocab)
# # Assume `vocab` is your vocabulary object
# with open('vocabulary_serializabled.pkl', 'wb') as f:
#     pickle.dump(vocab, f)
